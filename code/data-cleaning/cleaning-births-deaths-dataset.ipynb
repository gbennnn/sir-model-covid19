# %% [markdown]
# ### Data Preparation & Data Cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset : Births and Deaths projected to 2100
dataset_path = '../../dataset/our-worl-data/births-and-deaths-projected-to-2100.csv'
df = pd.read_csv(dataset_path)

# %%
df.shape
# Out:
# (151, 7)

# %%
df.head(100)
# Out:
#        Entity Code  Year  Deaths - Sex: all - Age: all - Variant: estimates  \
# 0   Indonesia  IDN  1950                                          1435160.0
# 1   Indonesia  IDN  1951                                          1444298.0
# 2   Indonesia  IDN  1952                                          1454169.9
# 3   Indonesia  IDN  1953                                          1468481.9
# 4   Indonesia  IDN  1954                                          1483242.0
# ..        ...  ...   ...                                                ...
# 95  Indonesia  IDN  2045                                                NaN
# 96  Indonesia  IDN  2046                                                NaN
# 97  Indonesia  IDN  2047                                                NaN
# 98  Indonesia  IDN  2048                                                NaN
# 99  Indonesia  IDN  2049                                                NaN
#
#     Deaths - Sex: all - Age: all - Variant: medium  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 95                                       3165872.0
# 96                                       3213025.0
# 97                                       3258542.0
# 98                                       3301831.0
# 99                                       3345086.0
#
#     Births - Sex: all - Age: all - Variant: estimates  \
# 0                                           2783163.0
# 1                                           2892411.0
# 2                                           3005894.0
# 3                                           3120435.0
# 4                                           3244910.0
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#     Births - Sex: all - Age: all - Variant: medium
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 95                                       4103530.8
# 96                                       4067058.0
# 97                                       4036947.0
# 98                                       4005891.0
# 99                                       3971275.0
#
# [100 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 7 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Entity                                             151 non-null    object
#  1   Code                                               151 non-null    object
#  2   Year                                               151 non-null    int64
#  3   Deaths - Sex: all - Age: all - Variant: estimates  74 non-null     float64
#  4   Deaths - Sex: all - Age: all - Variant: medium     77 non-null     float64
#  5   Births - Sex: all - Age: all - Variant: estimates  74 non-null     float64
#  6   Births - Sex: all - Age: all - Variant: medium     77 non-null     float64
# dtypes: float64(4), int64(1), object(2)
# memory usage: 8.4+ KB

# %%
df.describe()
# Out:
#               Year  Deaths - Sex: all - Age: all - Variant: estimates  \
# count   151.000000                                       7.400000e+01
# mean   2025.000000                                       1.664870e+06
# std      43.734045                                       2.457474e+05
# min    1950.000000                                       1.435160e+06
# 25%    1987.500000                                       1.510933e+06
# 50%    2025.000000                                       1.563824e+06
# 75%    2062.500000                                       1.753559e+06
# max    2100.000000                                       2.779186e+06
#
#        Deaths - Sex: all - Age: all - Variant: medium  \
# count                                    7.700000e+01
# mean                                     3.451120e+06
# std                                      5.597505e+05
# min                                      2.161269e+06
# 25%                                      3.071722e+06
# 50%                                      3.738411e+06
# 75%                                      3.895570e+06
# max                                      3.943967e+06
#
#        Births - Sex: all - Age: all - Variant: estimates  \
# count                                       7.400000e+01
# mean                                        4.544860e+06
# std                                         5.628311e+05
# min                                         2.783163e+06
# 25%                                         4.501296e+06
# 50%                                         4.737806e+06
# 75%                                         4.871008e+06
# max                                         5.157679e+06
#
#        Births - Sex: all - Age: all - Variant: medium
# count                                    7.700000e+01
# mean                                     3.660719e+06
# std                                      5.144732e+05
# min                                      2.825757e+06
# 25%                                      3.208328e+06
# 50%                                      3.634278e+06
# 75%                                      4.174009e+06
# max                                      4.468312e+06

# %%
"""
    Counts the number of missing values in each column of the DataFrame `df`.

    Note:
    - The null data corresponds to the years 2024 - 2100.
    - Only data up to the year 2023 is used in this analysis.
"""

df.isna().sum()
# Out:
# Entity                                                0
# Code                                                  0
# Year                                                  0
# Deaths - Sex: all - Age: all - Variant: estimates    77
# Deaths - Sex: all - Age: all - Variant: medium       74
# Births - Sex: all - Age: all - Variant: estimates    77
# Births - Sex: all - Age: all - Variant: medium       74
# dtype: int64

# %%
# Menghapus kolom births & deaths medium variant (2024 - 2100)
df.drop(columns=['Births - Sex: all - Age: all - Variant: medium', 'Deaths - Sex: all - Age: all - Variant: medium'], inplace=True)

# %%
df.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Deaths - Sex: all - Age: all - Variant: estimates',
#        'Births - Sex: all - Age: all - Variant: estimates'],
#       dtype='object')

# %%
df.head()
# Out:
#       Entity Code  Year  Deaths - Sex: all - Age: all - Variant: estimates  \
# 0  Indonesia  IDN  1950                                          1435160.0
# 1  Indonesia  IDN  1951                                          1444298.0
# 2  Indonesia  IDN  1952                                          1454169.9
# 3  Indonesia  IDN  1953                                          1468481.9
# 4  Indonesia  IDN  1954                                          1483242.0
#
#    Births - Sex: all - Age: all - Variant: estimates
# 0                                          2783163.0
# 1                                          2892411.0
# 2                                          3005894.0
# 3                                          3120435.0
# 4                                          3244910.0

# %%
# Menghapus baris yang memiliki nilai null (data tahun 2024 - 2100)
df.dropna(inplace=True)
df.isna().sum()
# Out:
# Entity                                               0
# Code                                                 0
# Year                                                 0
# Deaths - Sex: all - Age: all - Variant: estimates    0
# Births - Sex: all - Age: all - Variant: estimates    0
# dtype: int64

# %%
# Menyimpan hasil
df.to_csv('../../dataset/cleaned-data/cleaned_data_births_deaths.csv', index=False)
